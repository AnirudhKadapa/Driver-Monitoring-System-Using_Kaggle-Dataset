# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# C:\Users\anirudh\Desktop\misd\DDS

# %%
# !pip list
# Out:
# Package                  Version              Editable project location
# ------------------------ -------------------- -------------------------------------------------------
# absl-py                  1.4.0
# addict                   2.4.0
# anyio                    3.6.2
# apptools                 5.2.0
# argon2-cffi              21.3.0
# argon2-cffi-bindings     21.2.0
# arrow                    1.2.3
# asttokens                2.2.1
# attrs                    22.2.0
# backcall                 0.2.0
# beautifulsoup4           4.11.2
# black                    23.1.0
# bleach                   6.0.0
# brotlipy                 0.7.0
# cachetools               5.3.0
# certifi                  2022.12.7
# cffi                     1.15.1
# charset-normalizer       2.1.1
# click                    8.1.3
# colorama                 0.4.6
# comm                     0.1.2
# configobj                5.0.8
# contourpy                1.0.7
# cryptography             39.0.1
# ...

# %%
#!pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20  Python-3.8.10 torch-2.0.0+cpu CPU
# Setup complete  (8 CPUs, 7.9 GB RAM, 164.6/465.1 GB disk)

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !yolo task=detect mode=train model=r'Yolov8\yolov8n.pt' data=data.yaml epochs=50 batch=16 imgsz=640 plots=True pretrained=True seed=13
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
#       35/50      2.24G     0.8363     0.6195      1.234         66        640:  27%|##7       | 117/429 [00:08<00:19, 15.99it/s]
#       35/50      2.24G     0.8363     0.6195      1.234         66        640:  28%|##7       | 119/429 [00:08<00:19, 15.80it/s]
#       35/50      2.24G      0.836     0.6188      1.234         64        640:  28%|##7       | 119/429 [00:08<00:19, 15.80it/s]
#       35/50      2.24G     0.8358     0.6181      1.234         59        640:  28%|##7       | 119/429 [00:08<00:19, 15.80it/s]
# ...

# %%
# !yolo task=detect mode=predict model=r'C:\Users\anirudh\Desktop\misd\DDS\runs\detect\train3\weights\best.pt' source=r'C:\Users\anirudh\Desktop\misd\DDS\VID_20230420_142632.mp4' show=True imgsz=640 name=yolov8_test_video10 save=True
# Out:
# Ultralytics YOLOv8.0.20  Python-3.8.10 torch-2.0.0+cpu CPU
# Model summary (fused): 168 layers, 3008183 parameters, 0 gradients, 8.1 GFLOPs
# video 1/1 (1/3189) C:\Users\anirudh\Desktop\misd\DDS\VID_20230420_142632.mp4: 384x640 1 d0 - Eyes Closed, 1 d3 - Eyes Open, 218.7ms
# video 1/1 (2/3189) C:\Users\anirudh\Desktop\misd\DDS\VID_20230420_142632.mp4: 384x640 1 d0 - Eyes Closed, 1 d3 - Eyes Open, 171.8ms
# video 1/1 (3/3189) C:\Users\anirudh\Desktop\misd\DDS\VID_20230420_142632.mp4: 384x640 1 d0 - Eyes Closed, 1 d3 - Eyes Open, 140.6ms
# video 1/1 (4/3189) C:\Users\anirudh\Desktop\misd\DDS\VID_20230420_142632.mp4: 384x640 1 d0 - Eyes Closed, 1 d3 - Eyes Open, 194.2ms
# video 1/1 (5/3189) C:\Users\anirudh\Desktop\misd\DDS\VID_20230420_142632.mp4: 384x640 1 d0 - Eyes Closed, 1 d3 - Eyes Open, 171.8ms
# video 1/1 (6/3189) C:\Users\anirudh\Desktop\misd\DDS\VID_20230420_142632.mp4: 384x640 1 d0 - Eyes Closed, 1 d3 - Eyes Open, 125.0ms
# ...

# %%
# !yolo task=detect mode=predict model=r'C:\Users\anirudh\Desktop\misd\DDS\runs\detect\train3\weights\best.pt' source=r'C:\Users\anirudh\Desktop\misd\DDS\sai.mp4' show=True imgsz=640 name=yolov8_test_video10 save=True
# Out:
# Ultralytics YOLOv8.0.20  Python-3.8.10 torch-2.0.0+cpu CPU
# Model summary (fused): 168 layers, 3008183 parameters, 0 gradients, 8.1 GFLOPs
# video 1/1 (1/1810) C:\Users\anirudh\Desktop\misd\DDS\sai.mp4: 384x640 1 d0 - Eyes Closed, 93.7ms
# video 1/1 (2/1810) C:\Users\anirudh\Desktop\misd\DDS\sai.mp4: 384x640 1 d0 - Eyes Closed, 109.4ms
# video 1/1 (3/1810) C:\Users\anirudh\Desktop\misd\DDS\sai.mp4: 384x640 1 d0 - Eyes Closed, 104.2ms
# video 1/1 (4/1810) C:\Users\anirudh\Desktop\misd\DDS\sai.mp4: 384x640 1 d0 - Eyes Closed, 171.8ms
# video 1/1 (5/1810) C:\Users\anirudh\Desktop\misd\DDS\sai.mp4: 384x640 1 d0 - Eyes Closed, 1 d3 - Eyes Open, 171.8ms
# video 1/1 (6/1810) C:\Users\anirudh\Desktop\misd\DDS\sai.mp4: 384x640 1 d0 - Eyes Closed, 175.3ms
# video 1/1 (7/1810) C:\Users\anirudh\Desktop\misd\DDS\sai.mp4: 384x640 1 d0 - Eyes Closed, 156.2ms
# video 1/1 (8/1810) C:\Users\anirudh\Desktop\misd\DDS\sai.mp4: 384x640 1 d0 - Eyes Closed, 139.0ms
# ...
